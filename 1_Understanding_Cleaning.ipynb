# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('ola_booking.csv')
# Out:
# C:\Users\Jay Sunil Sonawane\AppData\Local\Temp\ipykernel_3840\71215642.py:1: DtypeWarning: Columns (0,1,2,3,4,5,6,7,10,11,12,13,15,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('ola_booking.csv')

# %%
data.head()
# Out:
#                   Date      Time     Booking_ID        Booking_Status  \
# 0  2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1  2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2  2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3   2024-07-22 3:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4   2024-07-02 9:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  ...  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN  ...
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0  ...
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0  ...
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN  ...
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0  ...
#
#        Canceled_Rides_by_Driver Incomplete_Rides Incomplete_Rides_Reason  \
# ...

# %%
data.shape
# Out:
# (103024, 21)

# %%
data.isnull().sum()
# Out:
# Date                           31823
# Time                           31823
# Booking_ID                     31823
# Booking_Status                 31823
# Customer_ID                    31823
# Vehicle_Type                   31823
# Pickup_Location                31823
# Drop_Location                  31823
# V_TAT                          58753
# C_TAT                          58753
# Canceled_Rides_by_Customer     95810
# Canceled_Rides_by_Driver       90296
# Incomplete_Rides               58753
# Incomplete_Rides_Reason       100339
# Booking_Value                  31823
# Payment_Method                 58753
# Ride_Distance                  31823
# Driver_Ratings                 58753
# Customer_Rating                58753
# Vehicle Images                 31823
# Unnamed: 20                   103024
# dtype: int64

# %%
data.isnull().mean() * 100
# Out:
# Date                           30.888919
# Time                           30.888919
# Booking_ID                     30.888919
# Booking_Status                 30.888919
# Customer_ID                    30.888919
# Vehicle_Type                   30.888919
# Pickup_Location                30.888919
# Drop_Location                  30.888919
# V_TAT                          57.028459
# C_TAT                          57.028459
# Canceled_Rides_by_Customer     92.997748
# Canceled_Rides_by_Driver       87.645597
# Incomplete_Rides               57.028459
# Incomplete_Rides_Reason        97.393811
# Booking_Value                  30.888919
# Payment_Method                 57.028459
# Ride_Distance                  30.888919
# Driver_Ratings                 57.028459
# Customer_Rating                57.028459
# Vehicle Images                 30.888919
# Unnamed: 20                   100.000000
# dtype: float64

# %%
data.duplicated().mean()*100
# Out:
# np.float64(30.88794843919863)

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.drop(columns=['Unnamed: 20','Vehicle Images'],axis=1,inplace=True)

# %%
data.dropna(how='all', inplace=True)

# %%
data.drop('Incomplete_Rides_Reason',axis=1,inplace=True)

# %%
data['Canceled_Rides_by_Customer'] = data['Canceled_Rides_by_Customer'].fillna('Reason not mentioned')

# %%
data['Canceled_Rides_by_Driver'] = data['Canceled_Rides_by_Driver'].fillna('Reason not specified')

# %%
data['Payment_Method'] = data['Payment_Method'].fillna('Not Provided')

# %%
data['Incomplete_Rides'] = data['Incomplete_Rides'].fillna('Nothing Mentioned')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71201 entries, 0 to 71200
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        71201 non-null  datetime64[ns]
#  1   Booking_ID                  71201 non-null  object
#  2   Booking_Status              71201 non-null  object
#  3   Customer_ID                 71201 non-null  object
#  4   Vehicle_Type                71201 non-null  object
#  5   Pickup_Location             71201 non-null  object
#  6   Drop_Location               71201 non-null  object
#  7   V_TAT                       44271 non-null  float64
#  8   C_TAT                       44271 non-null  float64
#  9   Canceled_Rides_by_Customer  71201 non-null  object
#  10  Canceled_Rides_by_Driver    71201 non-null  object
#  11  Incomplete_Rides            71201 non-null  object
#  12  Booking_Value               71201 non-null  float64
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['Only_Date'] = data['Date'].dt.date

# %%
data['Month'] = data['Date'].dt.month

# %%
data['Day_Name'] = data['Date'].dt.day_name()

# %%
data['Time'] = data['Date'].dt.time

# %%
data['Hour'] = data['Date'].dt.hour

# %%
data['Minute'] = data['Date'].dt.minute

# %%
data
# Out:
#                      Date     Booking_ID        Booking_Status Customer_ID  \
# 0     2024-07-26 14:00:00  CNR7153255142    Canceled by Driver   CID713523
# 1     2024-07-25 22:20:00  CNR2940424040               Success   CID225428
# 2     2024-07-30 19:59:00  CNR2982357879               Success   CID270156
# 3     2024-07-22 03:15:00  CNR2395710036  Canceled by Customer   CID581320
# 4     2024-07-02 09:02:00  CNR1797421769               Success   CID939555
# ...                   ...            ...                   ...         ...
# 71196 2024-07-19 09:48:00  CNR3193933852               Success   CID442451
# 71197 2024-07-16 05:02:00  CNR3906366271               Success   CID538007
# 71198 2024-07-03 22:14:00  CNR4789445170  Canceled by Customer   CID382728
# 71199 2024-07-29 12:17:00  CNR5806198441    Canceled by Driver   CID686055
# 71200 2024-07-19 21:38:00  CNR4531167950               Success   CID923283
#
# ...

# %%
def get_time_slot(hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour < 21:
        return 'Evening'
    else:
        return 'Night'

data['Time_Slot'] = data['Hour'].apply(get_time_slot)

# %%
data.head(20)
# Out:
#                   Date     Booking_ID        Booking_Status Customer_ID  \
# 0  2024-07-26 14:00:00  CNR7153255142    Canceled by Driver   CID713523
# 1  2024-07-25 22:20:00  CNR2940424040               Success   CID225428
# 2  2024-07-30 19:59:00  CNR2982357879               Success   CID270156
# 3  2024-07-22 03:15:00  CNR2395710036  Canceled by Customer   CID581320
# 4  2024-07-02 09:02:00  CNR1797421769               Success   CID939555
# 5  2024-07-13 04:42:00  CNR8787177882               Success   CID802429
# 6  2024-07-23 09:51:00  CNR3612067560               Success   CID476071
# 7  2024-07-11 11:12:00  CNR5374902489    Canceled by Driver   CID735691
# 8  2024-07-01 19:19:00  CNR5030602354      Driver Not Found   CID999840
# 9  2024-07-18 01:31:00  CNR6328453219    Canceled by Driver   CID907133
# 10 2024-07-29 23:33:00  CNR4787583516               Success   CID923404
# 11 2024-07-26 04:03:00  CNR7943634301               Success   CID647026
# ...

# %%
data['IS_WEEKEND'] = data['Day_Name'].isin(['Saturday', 'Sunday'])

# %%
data['IS_WEEKEND'] = data['IS_WEEKEND'].astype(int)

# %%
data.columns
# Out:
# Index(['Booking_ID', 'Booking_Status', 'Customer_ID', 'Vehicle_Type',
#        'Pickup_Location', 'Drop_Location', 'V_TAT', 'C_TAT',
#        'Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver',
#        'Incomplete_Rides', 'Booking_Value', 'Payment_Method', 'Ride_Distance',
#        'Driver_Ratings', 'Customer_Rating', 'Only_Date', 'Month', 'Day_Name',
#        'Time', 'Hour', 'Time_Slot', 'IS_WEEKEND'],
#       dtype='object')

# %%
new_order = [
    'Booking_ID', 'Customer_ID', 'Booking_Status',
    'Vehicle_Type', 'Pickup_Location', 'Drop_Location', 'Ride_Distance',
    'Only_Date', 'Month', 'Day_Name','IS_WEEKEND', 'Hour', 'Time', 'Time_Slot',
    'V_TAT', 'C_TAT',
    'Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver', 'Incomplete_Rides',
    'Booking_Value', 'Payment_Method', 'Driver_Ratings', 'Customer_Rating'
]

data = data[new_order]

# %%
data
# Out:
#           Booking_ID Customer_ID        Booking_Status Vehicle_Type  \
# 0      CNR7153255142   CID713523    Canceled by Driver  Prime Sedan
# 1      CNR2940424040   CID225428               Success         Bike
# 2      CNR2982357879   CID270156               Success    Prime SUV
# 3      CNR2395710036   CID581320  Canceled by Customer        eBike
# 4      CNR1797421769   CID939555               Success         Mini
# ...              ...         ...                   ...          ...
# 71196  CNR3193933852   CID442451               Success         Auto
# 71197  CNR3906366271   CID538007               Success   Prime Plus
# 71198  CNR4789445170   CID382728  Canceled by Customer   Prime Plus
# 71199  CNR5806198441   CID686055    Canceled by Driver         Bike
# 71200  CNR4531167950   CID923283               Success    Prime SUV
#
#             Pickup_Location         Drop_Location  Ride_Distance   Only_Date  \
# ...

# %%
data.to_csv('Final_Booking_Data.csv', index=False)
